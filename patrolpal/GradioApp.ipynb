# %% [markdown]
# # Imports

# %%
# !pip install deepface
# !pip install retina-face
# !pip install ray
# !pip install moviepy
# !pip install imgaug
# !pip install h5py
# !pip install pycocotools
# !pip install cython
# !pip install tensorflow-gpu
# !pip install opencv-python
# !pip install scikit-image
# !pip install scikit-learn
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# !pip install numpy
# !pip install gradio
# !pip install imageio_ffmpeg
# Out:
# Collecting deepface
#   Downloading deepface-0.0.75-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 2.2 MB/s eta 0:00:00
# Collecting Pillow>=5.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 6.3 MB/s eta 0:00:000:00:010:00:01:01
# Collecting pandas>=0.23.4
#   Downloading pandas-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 6.3 MB/s eta 0:00:006.5 MB/s eta 0:00:01
# Collecting gdown>=3.10.1
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fire>=0.4.0
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow>=1.9.0
#   Downloading tensorflow-2.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting Flask>=1.1.2
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 2.8 MB/s eta 0:00:00
# Collecting opencv-python>=4.5.5.64
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tqdm>=4.30.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.2 MB/s eta 0:00:00
# Collecting numpy>=1.14.0
#   Downloading numpy-1.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.12-py3-none-any.whl (15 kB)
# Collecting keras>=2.2.0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: six in ./lib/python3.10/site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting click>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 7.2 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: Jinja2>=3.0 in ./lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Collecting Werkzeug>=2.2.2
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 5.0 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: beautifulsoup4 in ./lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Collecting requests[socks]
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.9 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 kB 5.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in ./lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 5.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 9.2 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 6.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.47.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: packaging in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (21.3)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 5.7 MB/s eta 0:00:005.8 MB/s eta 0:00:01
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 4.9 MB/s eta 0:00:005.4 MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (63.4.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 6.1 MB/s eta 0:00:006.5 MB/s eta 0:00:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 7.9 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.10.0-py2.py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 5.5 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 5.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: soupsieve>1.2 in ./lib/python3.10/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./lib/python3.10/site-packages (from packaging->tensorflow>=1.9.0->deepface) (3.0.9)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 6.2 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.0 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 4.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.7 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.8 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 8.3 MB/s eta 0:00:00
# Building wheels for collected packages: fire, gdown, termcolor
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115926 sha256=b5d6b382df47b22893d6064a94e44c3dec0167e9b3e17739ae01bf28458d8c19
#   Stored in directory: /home/adarsh/.cache/pip/wheels/26/9a/dd/2818b1b023daf077ec3e625c47ae446aca587a5abe48e05212
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=5267fced021edd69b3e09d45f38941438790f5f9b27efecb25c14da9b4d0f31e
#   Stored in directory: /home/adarsh/.cache/pip/wheels/38/72/83/dab5cb8321023eb1549d7a7d7f564b479ed4cf71edb70ddad6
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=b38750ad4b280dc4ebdf43dfdea4ccedd5f87368c89a67301d4acb44a0865143
#   Stored in directory: /home/adarsh/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built fire gdown termcolor
# Installing collected packages: termcolor, tensorboard-plugin-wit, pytz, pyasn1, libclang, keras, flatbuffers, wrapt, Werkzeug, urllib3, typing-extensions, tqdm, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, PySocks, pyasn1-modules, protobuf, Pillow, oauthlib, numpy, markdown, itsdangerous, idna, grpcio, google-pasta, gast, fire, filelock, click, charset-normalizer, certifi, cachetools, astunparse, absl-py, requests, pandas, opt-einsum, opencv-python, keras-preprocessing, h5py, google-auth, Flask, requests-oauthlib, mtcnn, google-auth-oauthlib, gdown, tensorboard, tensorflow, retina-face, deepface
# Successfully installed Flask-2.2.2 Pillow-9.2.0 PySocks-1.7.1 Werkzeug-2.2.2 absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.6.15 charset-normalizer-2.1.0 click-8.1.3 deepface-0.0.75 filelock-3.8.0 fire-0.4.0 flatbuffers-1.12 gast-0.4.0 gdown-4.5.1 google-auth-2.10.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 h5py-3.7.0 idna-3.3 itsdangerous-2.1.2 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 mtcnn-0.1.1 numpy-1.23.1 oauthlib-3.2.0 opencv-python-4.6.0.66 opt-einsum-3.3.0 pandas-1.4.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2022.2.1 requests-2.28.1 requests-oauthlib-1.3.1 retina-face-0.0.12 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0 tqdm-4.64.0 typing-extensions-4.3.0 urllib3-1.26.11 wrapt-1.14.1
# Requirement already satisfied: retina-face in ./lib/python3.10/site-packages (0.0.12)
# Requirement already satisfied: tensorflow>=1.9.0 in ./lib/python3.10/site-packages (from retina-face) (2.9.1)
# Requirement already satisfied: gdown>=3.10.1 in ./lib/python3.10/site-packages (from retina-face) (4.5.1)
# Requirement already satisfied: Pillow>=5.2.0 in ./lib/python3.10/site-packages (from retina-face) (9.2.0)
# Requirement already satisfied: numpy>=1.14.0 in ./lib/python3.10/site-packages (from retina-face) (1.23.1)
# Requirement already satisfied: opencv-python>=3.4.4 in ./lib/python3.10/site-packages (from retina-face) (4.6.0.66)
# Requirement already satisfied: requests[socks] in ./lib/python3.10/site-packages (from gdown>=3.10.1->retina-face) (2.28.1)
# Requirement already satisfied: tqdm in ./lib/python3.10/site-packages (from gdown>=3.10.1->retina-face) (4.64.0)
# Requirement already satisfied: beautifulsoup4 in ./lib/python3.10/site-packages (from gdown>=3.10.1->retina-face) (4.11.1)
# Requirement already satisfied: filelock in ./lib/python3.10/site-packages (from gdown>=3.10.1->retina-face) (3.8.0)
# Requirement already satisfied: six in ./lib/python3.10/site-packages (from gdown>=3.10.1->retina-face) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (4.3.0)
# Requirement already satisfied: packaging in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (21.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.14.1)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (63.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.47.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (3.19.4)
# Requirement already satisfied: libclang>=13.0.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (14.0.6)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (0.26.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (3.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./lib/python3.10/site-packages (from tensorflow>=1.9.0->retina-face) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->retina-face) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (2.10.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in ./lib/python3.10/site-packages (from beautifulsoup4->gdown>=3.10.1->retina-face) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./lib/python3.10/site-packages (from packaging->tensorflow>=1.9.0->retina-face) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.7.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->retina-face) (3.2.0)
# Collecting ray
#   Downloading ray-1.13.0-cp310-cp310-manylinux2014_x86_64.whl (54.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 MB 5.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 6.1 MB/s eta 0:00:006.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.3 in ./lib/python3.10/site-packages (from ray) (1.23.1)
# Requirement already satisfied: requests in ./lib/python3.10/site-packages (from ray) (2.28.1)
# Requirement already satisfied: attrs in ./lib/python3.10/site-packages (from ray) (22.1.0)
# Collecting aiosignal
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting virtualenv
#   Downloading virtualenv-20.16.3-py2.py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 5.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: jsonschema in ./lib/python3.10/site-packages (from ray) (4.9.1)
# Requirement already satisfied: filelock in ./lib/python3.10/site-packages (from ray) (3.8.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in ./lib/python3.10/site-packages (from ray) (3.19.4)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 kB 6.2 MB/s eta 0:00:005.7 MB/s eta 0:00:01
# Collecting frozenlist
#   Downloading frozenlist-1.3.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 3.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting click<=8.0.4,>=7.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5.2 in ./lib/python3.10/site-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./lib/python3.10/site-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests->ray) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./lib/python3.10/site-packages (from requests->ray) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests->ray) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./lib/python3.10/site-packages (from requests->ray) (1.26.11)
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.5-py2.py3-none-any.whl (466 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.0/467.0 kB 5.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: msgpack, distlib, pyyaml, platformdirs, grpcio, frozenlist, click, virtualenv, aiosignal, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.47.0
#     Uninstalling grpcio-1.47.0:
#       Successfully uninstalled grpcio-1.47.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# Successfully installed aiosignal-1.2.0 click-8.0.4 distlib-0.3.5 frozenlist-1.3.1 grpcio-1.43.0 msgpack-1.0.4 platformdirs-2.5.2 pyyaml-6.0 ray-1.13.0 virtualenv-20.16.3
# ERROR: Can not perform a '--user' install. User site-packages are not visible in this virtualenv.
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting imageio
#   Downloading imageio-2.21.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 5.6 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.15 in ./lib/python3.10/site-packages (from imgaug) (1.23.1)
# Requirement already satisfied: opencv-python in ./lib/python3.10/site-packages (from imgaug) (4.6.0.66)
# Collecting scipy
#   Downloading scipy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 5.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting Shapely
#   Downloading Shapely-1.8.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.5 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: Pillow in ./lib/python3.10/site-packages (from imgaug) (9.2.0)
# Collecting scikit-image>=0.14.2
#   Downloading scikit_image-0.19.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six in ./lib/python3.10/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from scikit-image>=0.14.2->imgaug) (21.3)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.8.12-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 5.7 MB/s eta 0:00:000:00:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting networkx>=2.2
#   Downloading networkx-2.8.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in ./lib/python3.10/site-packages (from matplotlib->imgaug) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 5.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.10/site-packages (from matplotlib->imgaug) (2.8.2)
# Installing collected packages: tifffile, Shapely, scipy, PyWavelets, networkx, kiwisolver, imageio, fonttools, cycler, scikit-image, matplotlib, imgaug
# Successfully installed PyWavelets-1.3.0 Shapely-1.8.2 cycler-0.11.0 fonttools-4.34.4 imageio-2.21.1 imgaug-0.4.0 kiwisolver-1.4.4 matplotlib-3.5.3 networkx-2.8.5 scikit-image-0.19.3 scipy-1.9.0 tifffile-2022.8.12
# Requirement already satisfied: h5py in ./lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.14.5 in ./lib/python3.10/site-packages (from h5py) (1.23.1)
# Collecting pycocotools
#   Downloading pycocotools-2.0.4.tar.gz (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in ./lib/python3.10/site-packages (from pycocotools) (3.5.3)
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (from pycocotools) (1.23.1)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.34.4)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.4-cp310-cp310-linux_x86_64.whl size=346737 sha256=1d8e6cdc07a7fb43a2341f65f020892828551a7b28bf1fdf87dfdf4446092ecc
#   Stored in directory: /home/adarsh/.cache/pip/wheels/a6/32/80/d5fe20c79fd05d626c0bc0ee44294db21b674267b2271588fa
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.4
# Collecting cython
#   Using cached Cython-0.29.32-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Installing collected packages: cython
# Successfully installed cython-0.29.32
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: opt-einsum>=2.3.2 in ./lib/python3.10/site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in ./lib/python3.10/site-packages (from tensorflow-gpu) (3.19.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./lib/python3.10/site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.43.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./lib/python3.10/site-packages (from tensorflow-gpu) (4.3.0)
# Requirement already satisfied: libclang>=13.0.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./lib/python3.10/site-packages (from tensorflow-gpu) (0.26.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in ./lib/python3.10/site-packages (from tensorflow-gpu) (2.9.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.23.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (2.9.0)
# Requirement already satisfied: packaging in ./lib/python3.10/site-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: termcolor>=1.1.0 in ./lib/python3.10/site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./lib/python3.10/site-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from tensorflow-gpu) (63.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./lib/python3.10/site-packages (from packaging->tensorflow-gpu) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.26.11)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in ./lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.2.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.9.1
# Requirement already satisfied: opencv-python in ./lib/python3.10/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in ./lib/python3.10/site-packages (from opencv-python) (1.23.1)
# Requirement already satisfied: scikit-image in ./lib/python3.10/site-packages (0.19.3)
# Requirement already satisfied: imageio>=2.4.1 in ./lib/python3.10/site-packages (from scikit-image) (2.21.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./lib/python3.10/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in ./lib/python3.10/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: numpy>=1.17.0 in ./lib/python3.10/site-packages (from scikit-image) (1.23.1)
# Requirement already satisfied: networkx>=2.2 in ./lib/python3.10/site-packages (from scikit-image) (2.8.5)
# Requirement already satisfied: scipy>=1.4.1 in ./lib/python3.10/site-packages (from scikit-image) (1.9.0)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in ./lib/python3.10/site-packages (from scikit-image) (2022.8.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./lib/python3.10/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in ./lib/python3.10/site-packages (from scikit-learn) (1.23.1)
# Requirement already satisfied: scipy>=1.3.2 in ./lib/python3.10/site-packages (from scikit-learn) (1.9.0)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 4.0 MB/s eta 0:00:004.8 MB/s eta 0:00:01
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.2 threadpoolctl-3.1.0
# Requirement already satisfied: pandas in ./lib/python3.10/site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.21.0 in ./lib/python3.10/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in ./lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in ./lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in ./lib/python3.10/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scipy in ./lib/python3.10/site-packages (1.9.0)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in ./lib/python3.10/site-packages (from scipy) (1.23.1)
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (1.23.1)
# Collecting gradio
#   Downloading gradio-3.1.4-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 6.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy in ./lib/python3.10/site-packages (from gradio) (1.23.1)
# Collecting orjson
#   Downloading orjson-3.7.11-cp310-cp310-manylinux_2_28_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 3.7 MB/s eta 0:00:008.5 MB/s eta 0:00:01
# Requirement already satisfied: pillow in ./lib/python3.10/site-packages (from gradio) (9.2.0)
# Requirement already satisfied: matplotlib in ./lib/python3.10/site-packages (from gradio) (3.5.3)
# Collecting pycryptodome
#   Downloading pycryptodome-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 7.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pydantic
#   Downloading pydantic-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 2.8 MB/s eta 0:00:004.5 MB/s eta 0:00:01
# Collecting analytics-python
#   Downloading analytics_python-1.4.0-py2.py3-none-any.whl (15 kB)
# Collecting fsspec
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 2.9 MB/s eta 0:00:005.1 MB/s eta 0:00:01
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in ./lib/python3.10/site-packages (from gradio) (2.28.1)
# Requirement already satisfied: Jinja2 in ./lib/python3.10/site-packages (from gradio) (3.1.2)
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 1.5 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in ./lib/python3.10/site-packages (from gradio) (1.4.3)
# Collecting fastapi
#   Downloading fastapi-0.79.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.9 MB/s eta 0:00:00
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 1.6 MB/s eta 0:00:005.6 MB/s eta 0:00:01
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.18.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 10.7 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.6 MB/s eta 0:00:000:00:01
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.0/264.0 kB 5.0 MB/s eta 0:00:009.0 MB/s eta 0:00:01
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in ./lib/python3.10/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in ./lib/python3.10/site-packages (from aiohttp->gradio) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./lib/python3.10/site-packages (from aiohttp->gradio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in ./lib/python3.10/site-packages (from aiohttp->gradio) (22.1.0)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: python-dateutil>2.1 in ./lib/python3.10/site-packages (from analytics-python->gradio) (2.8.2)
# Collecting backoff==1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from analytics-python->gradio) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests->gradio) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./lib/python3.10/site-packages (from requests->gradio) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests->gradio) (3.3)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 4.8 MB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Using cached anyio-3.6.1-py3-none-any.whl (80 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./lib/python3.10/site-packages (from pydantic->gradio) (4.3.0)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 11.1 MB/s eta 0:00:00
# Collecting sniffio
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from Jinja2->gradio) (2.1.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.1-py3-none-any.whl (10 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.5 MB/s eta 0:00:00
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in ./lib/python3.10/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib->gradio) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib->gradio) (21.3)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.10/site-packages (from pandas->gradio) (2022.2.1)
# Collecting cryptography>=2.5
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 1.5 MB/s eta 0:00:000:00:01
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: click>=7.0 in ./lib/python3.10/site-packages (from uvicorn->gradio) (8.0.4)
# Requirement already satisfied: cffi>=1.1 in ./lib/python3.10/site-packages (from bcrypt>=3.1.3->paramiko->gradio) (1.15.1)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: pycparser in ./lib/python3.10/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->gradio) (2.21)
# Building wheels for collected packages: ffmpy, python-multipart
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4693 sha256=affea30adf4afa99f8ac113aec17030a71de00d3f5e061c831c512d3c5da4390
#   Stored in directory: /home/adarsh/.cache/pip/wheels/0c/c2/0e/3b9c6845c6a4e35beb90910cc70d9ac9ab5d47402bd62af0df
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31671 sha256=6dd1fc7543ffcbde3dc2badab0b9d81532046b342ddc52fe949403e6ec9e9fd9
#   Stored in directory: /home/adarsh/.cache/pip/wheels/ae/3f/03/fa4bd98cd7f4a25e63b6a0b61a7a8352e0f874cd9de1f3390d
# Successfully built ffmpy python-multipart
# Installing collected packages: rfc3986, pydub, monotonic, ffmpy, uc-micro-py, sniffio, python-multipart, pydantic, pycryptodome, orjson, multidict, mdurl, h11, fsspec, backoff, async-timeout, yarl, uvicorn, pynacl, markdown-it-py, linkify-it-py, cryptography, bcrypt, anyio, analytics-python, starlette, paramiko, mdit-py-plugins, httpcore, aiohttp, httpx, fastapi, gradio
# Successfully installed aiohttp-3.8.1 analytics-python-1.4.0 anyio-3.6.1 async-timeout-4.0.2 backoff-1.10.0 bcrypt-3.2.2 cryptography-37.0.4 fastapi-0.79.0 ffmpy-0.3.0 fsspec-2022.7.1 gradio-3.1.4 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.0 mdurl-0.1.1 monotonic-1.6 multidict-6.0.2 orjson-3.7.11 paramiko-2.11.0 pycryptodome-3.15.0 pydantic-1.9.2 pydub-0.25.1 pynacl-1.5.0 python-multipart-0.0.5 rfc3986-1.5.0 sniffio-1.2.0 starlette-0.19.1 uc-micro-py-1.0.1 uvicorn-0.18.2 yarl-1.8.1
# Collecting imageio_ffmpeg
#   Downloading imageio_ffmpeg-0.4.7-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: imageio_ffmpeg
# Successfully installed imageio_ffmpeg-0.4.7

# %%
import cv2
import os
import shutil
from pathlib import Path
import keras
from deepface import DeepFace
from retinaface import RetinaFace
import cv2
# from google.colab import files
from zipfile import ZipFile
import os
import shutil
from datetime import date
# from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import smtplib
import gradio as gr
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import time as tm
import ray
import numpy as np
import glob
from PIL import Image
ray.shutdown()
ray.init()
# Out:
# 2022-12-23 12:04:23.053253: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/adarsh/jupyter/environment/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-12-23 12:04:23.053277: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# RayContext(dashboard_url='', python_version='3.10.6', ray_version='1.13.0', ray_commit='e4ce38d001dbbe09cd21c497fedd03d692b2be3e', address_info={'node_ip_address': '192.168.1.208', 'raylet_ip_address': '192.168.1.208', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-12-23_12-04-26_357710_52368/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-12-23_12-04-26_357710_52368/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2022-12-23_12-04-26_357710_52368', 'metrics_export_port': 62250, 'gcs_address': '192.168.1.208:49849', 'address': '192.168.1.208:49849', 'node_id': '983722e909f7d6e8b11777d6207f5cf045313393be5627994ea37d8a'})

# %%
# # from google.colab import drive
# # drive.mount('/content/drive',force_remount=True)
# !pwd

# %%
@ray.remote
def func1(frame_name,filename,alpha,beta,output_storage_path,queryPath,detected_op_path,detected_freq,flag):
  nd=[]
  print(filename,"FILENAME")
  frames = []

  cap = cv2.VideoCapture(filename)
  print(cap)
  dflag=0
  while True:
    text_file = open(output_storage_path + "/person_coordinates.txt", 'a')
    ret, frame = cap.read()
    #print("hello")
    if(not ret):
      print("Please check your video quality or Your video file maybe corrupted!")
      break
    if(ret):

      if(frame_name%25==0):
        frame=cv2.addWeighted(frame,alpha,np.zeros(frame.shape,frame.dtype),0,beta)
        if(flag==1):
          cv2.imwrite(output_storage_path+filename.split("/")[-1][:-6]+".mp4"+"/"+str(frame_name)+".jpg", frame)
          print(output_storage_path+filename.split("/")[-1][:-6]+".mp4"+"/"+str(frame_name)+".jpg")
        else:
          cv2.imwrite(output_storage_path+filename.split("/")[-1]+"/"+str(frame_name)+".jpg", frame)
          print(output_storage_path+filename.split("/")[-1]+"/"+str(frame_name)+".jpg")
        try:
          if(flag==1):
            obj = DeepFace.verify(output_storage_path+filename.split("/")[-1][:-6]+".mp4"+"/"+str(frame_name)+".jpg", queryPath, model_name = 'ArcFace', detector_backend = 'retinaface')
          else:
            obj = DeepFace.verify(output_storage_path+filename.split("/")[-1]+"/"+str(frame_name)+".jpg", queryPath, model_name = 'ArcFace', detector_backend = 'retinaface')

          if(obj["verified"]==True or obj['distance']<.8):            
            cv2.imwrite(detected_op_path+str(frame_name)+".jpg",frame)
            print("Person of Interest detected in Frame No.",frame_name)
            detected_freq+=1
            text_file.write(str(frame_name)+"\n")
            frames.append(frame_name)

        except:

          print("no face")
          nd.append(frame_name)
        
        if(detected_freq>=2):
          break
    frame_name+=1
    text_file.close()
  return nd, frame_name

# %%
def patrolPal(file_obj, query_obj):
    # uploaded = files.upload()
    #print(uploaded)
    # filename = next(iter(file_obj))
    filename = file_obj.name
    print(filename)
    print(file_obj.name, query_obj.name)
    list_of_cctv_vids=[]

    if not os.path.isdir('content/drive/MyDrive/person-modeltest/person-identify/'):
        os.makedirs('content/drive/MyDrive/person-modeltest/person-identify/Detected Frames/')
        os.makedirs('content/drive/MyDrive/person-modeltest/person-identify/output/')
        
    shutil.unpack_archive(filename, "content/drive/MyDrive"+filename)
    for filepath in os.listdir("content/drive/MyDrive"+filename):
        f = os.path.join(filename, filepath)
        # checking if it is a file
        print(f)
        list_of_cctv_vids.append("content/drive/MyDrive"+f)

    #print("Files inside the uploaded Zip Folder : ")
    print(list_of_cctv_vids)

    #print(uploaded)
    queryFileName = query_obj.name
    queryPath=queryFileName

    print(queryPath,"is the query image uploaded")

    #Redundant frame removal

    #list_of_cctv_vids=['/content/drive/MyDrive/case 5 files.zip/av-roundabout_pz3dg56a_new.mp4', '/content/drive/MyDrive/case 5 files.zip/cctv-1_new.mp4']

    # temp_list=[]
    # for i in list_of_cctv_vids:
    #     j=i[:-4]+'_new.'+i[-3:]
    #     os.popen("ffmpeg -i {input} -vf mpdecimate=hi=8000:lo=8000:frac=1:max=500 {output}".format(input = i, output = j))
    #     temp_list.append(j)
    
    # tm.sleep(120)

    # list_of_cctv_vids=temp_list
    print(list_of_cctv_vids)

    # for i in list_of_cctv_vids:
    #     vid2=i
    #     cam2 = cv2.VideoCapture(vid2)
    #     video_length = int(cam2.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    #     print ("Number of frames in modified video: ", video_length)

        
    #Folder hierarchy module
    today=date.today()
    directory = "Detected Frames/"+str(today)
    parent_dir = "content/drive/MyDrive/person-modeltest/person-identify/"
    path = os.path.join(parent_dir, directory)
    CHECK_FOLDER = os.path.isdir(path)
    if not CHECK_FOLDER:
        os.mkdir(path)
        print("Date Directory created")
    else:
        print("Directory already exists")

    
    for i in list_of_cctv_vids:
      temp=i.split("/")[-1]
      newfolder=os.path.join(path+"/", temp)
      CHECK_FOLDER = os.path.isdir(newfolder)
      if not CHECK_FOLDER:
        os.mkdir(newfolder)
        print(temp," Directory created")
      else:
        print("Directory already exists")

    path="content/drive/MyDrive/person-modeltest/person-identify/output/"
    for i in list_of_cctv_vids:
        temp=i.split("/")[-1]
        newfolder=os.path.join(path+"/", temp)
        CHECK_FOLDER = os.path.isdir(newfolder)
        if not CHECK_FOLDER:
            os.mkdir(newfolder)
            print("New Output Directory created")
        else:
            print("Output Directory already exists")

    #creating a directory to save only the frames where the person is detected

    path="content/drive/MyDrive/person-modeltest/person-identify/Detected Frames/"+str(today)
    for i in list_of_cctv_vids:
        temp=i.split("/")[-1]+"/"+"Face Recognition"
        newfolder=os.path.join(path+"/", temp)
        CHECK_FOLDER = os.path.isdir(newfolder)
        if not CHECK_FOLDER:
            os.mkdir(newfolder)
            print("New Face Recognition Directory created")
        else:
            print("Face Recognition Directory already exists")
        temp=i.split("/")[-1]+"/"+"Person Identification"
        newfolder=os.path.join(path+"/", temp)
        CHECK_FOLDER = os.path.isdir(newfolder)
        if not CHECK_FOLDER:
            os.mkdir(newfolder)
            print("New Person Identification Directory created")
        else:
            print("Person Identification Directory already exists")

    #creating textfiles to save the coordinate positions of the detected person
    path="content/drive/MyDrive/person-modeltest/person-identify/output/"
    for i in list_of_cctv_vids:
        temp=i.split("/")[-1]+"/"+"person_coordinates.txt"
        my_file = open(os.path.join(path, temp),"w+")
        my_file.close()
    
    #to maintain a list containing frames not detected by facial recognition module
    not_detected=[[]]*len(list_of_cctv_vids)
    #setting parameters for video frames enhancement
    alpha = 1.33  
    beta = -50
    for v in range(len(list_of_cctv_vids)):
        print("Analyzing video ",list_of_cctv_vids[v].split("/")[-1])
        detected_freq=0
        #list to contain information about the split up seconds of video into two halves
        times=[]

        output_storage_path="content/drive/MyDrive/person-modeltest/person-identify/output/"
        detected_op_path="content/drive/MyDrive/person-modeltest/person-identify/Detected Frames/"+str(date.today())+"/"+list_of_cctv_vids[v].split("/")[-1]+"/Face Recognition/"
        #cap = cv2.VideoCapture(input_video_path)

        #loading the video
        data = cv2.VideoCapture(list_of_cctv_vids[v])

        # count the number of frames in th evideo
        frames = data.get(cv2.CAP_PROP_FRAME_COUNT)
        #total no.of frames in the video
        fps = int(data.get(cv2.CAP_PROP_FPS))
        print("fps", fps)

        # calculate dusration of the video
        cutoff_len=0
        #total seconds of video
        seconds = int(frames / fps)

        #list to contain the two new split video's address
        img_pths=[]
        if(seconds>20):
            #mid point of the video in seconds
            first_half=seconds//2
            #storing 0-mid an mid-end info in times list
            times.append("0-"+str(first_half))
            times.append(str(first_half)+"-"+str(seconds))
            
            for time in times:
                #starting time of each subclip
                starttime = int(time.split("-")[0])
                #ending time of subclip
                endtime = int(time.split("-")[1])
                #no. of seconds in subclip
                cutoff=(endtime-starttime)*fps
                if(times.index(time)==0):
                    cutoff_len=cutoff
                #creating the subclip andsaving to the videos folder
                ffmpeg_extract_subclip(list_of_cctv_vids[v], starttime, endtime, targetname=list_of_cctv_vids[v][:-4]+"#"+str(times.index(time)+1)+".mp4")
                print("Path of the subclip no.",str(times.index(time)+1)+" : "+list_of_cctv_vids[v][:-4]+"#"+str(times.index(time)+1)+".mp4")
                img_pths.append(list_of_cctv_vids[v][:-4]+"#"+str(times.index(time)+1)+".mp4")
            tm.sleep(120)
            
            # running the analysis module parallely forboth subclips
            impl1=func1.remote(0,img_pths[0],1.33,-50,output_storage_path,queryPath,detected_op_path,0,1)
            impl2=func1.remote(cutoff_len,img_pths[1],1.33,-50,output_storage_path,queryPath,detected_op_path,0,1)
            
            x,y=ray.get([impl1,impl2])
            print(x,y)
            #for i in range(len(y)):
            #w[i]=cutoff_len+w[i]
            #print(x+y,"gives undetected")
            x=x+y
            not_detected[v]=x
        else:
            img_pths.append(list_of_cctv_vids[v])
            impl1=func1.remote(0,img_pths[0],1.33,-50,output_storage_path,queryPath,detected_op_path,0,0)
            x=ray.get([impl1])
            print(x)
            not_detected[v].extend(x)
        #print(x,"gives undetected")
        print("Frames in each video which are not detected :",not_detected)
        for i in range(len(list_of_cctv_vids)):
            if not_detected[i]==[[]]:
                not_detected[i]=[]
        
        print(output_storage_path, list_of_cctv_vids)

        op = []
        valid_images = [".jpg",".gif",".png",".tga"]
        
        for i in list_of_cctv_vids:
          for f in os.listdir("content/drive/MyDrive/person-modeltest/person-identify/Detected Frames/"+str(today)+"/"+i.split("/")[-1]+"/Face Recognition/"):
            ext = os.path.splitext(f)[1]
            if ext.lower() not in valid_images:
              op.append(Image.open("content/drive/MyDrive/imageNotFound.jpeg"))
              continue
            else:
              op.append(Image.open(os.path.join("content/drive/MyDrive/person-modeltest/person-identify/Detected Frames/"+str(today)+"/"+i.split("/")[-1]+"/Face Recognition/",f)))
              break
        while(len(op)<5):
          op.append(Image.open("imageNotFound.jpeg"))

        print(op)

        opText = []
        for i in list_of_cctv_vids:
          opText.append(i.split("/")[-1])
        while(len(opText)<5):
          opText.append("No file provided!")


    return opText[0], op[0], opText[1], op[1], opText[2], op[2], opText[3], op[3], opText[4], op[4]

# %%
demo = gr.Interface(title = "Patrol Pal", description="Face recogntion application",fn=patrolPal, inputs=["file","file"], outputs=[gr.Textbox(label="file name", placeholder="Filename will be displayed after running.."), gr.Image(type='PIL.Image'), gr.Textbox(label="file name", placeholder="Filename will be displayed after running.."), gr.Image(type='PIL.Image'),gr.Textbox(label="file name", placeholder="Filename will be displayed after running.."), gr.Image(type='PIL.Image'), gr.Textbox(label="file name", placeholder="Filename will be displayed after running.."), gr.Image(type='PIL.Image'), gr.Textbox(label="file name", placeholder="Filename will be displayed after running.."), gr.Image(type='PIL.Image')])
# Out:
# IMPORTANT: You are using gradio version 3.1.4, however version 3.14.0 is available, please upgrade.
# --------

# %%
demo.launch(debug=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861/
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# /tmp/cctvbh90piyo.zip
# /tmp/cctvbh90piyo.zip /tmp/Query_Image6vkjpy6i.PNG
# /tmp/cctvbh90piyo.zip/av-roundabout_pz3dg56a.mp4
# ['content/drive/MyDrive/tmp/cctvbh90piyo.zip/av-roundabout_pz3dg56a.mp4']
# /tmp/Query_Image6vkjpy6i.PNG is the query image uploaded
# ['content/drive/MyDrive/tmp/cctvbh90piyo.zip/av-roundabout_pz3dg56a.mp4']
# Date Directory created
# av-roundabout_pz3dg56a.mp4  Directory created
# New Output Directory created
# New Face Recognition Directory created
# New Person Identification Directory created
# Analyzing video  av-roundabout_pz3dg56a.mp4
# fps 25
# (func1 pid=52617) content/drive/MyDrive/tmp/cctvbh90piyo.zip/av-roundabout_pz3dg56a.mp4 FILENAME
# (func1 pid=52617) < cv2.VideoCapture 0x7f3735bba9d0>
# (func1 pid=52617) content/drive/MyDrive/person-modeltest/person-identify/output/av-roundabout_pz3dg56a.mp4/0.jpg
# 1/1 [==============================] - 1s 668ms/step
# 1/1 [==============================] - 0s 67ms/step
# (func1 pid=52617) Person of Interest detected in Frame No. 0
# (func1 pid=52617) content/drive/MyDrive/person-modeltest/person-identify/output/av-roundabout_pz3dg56a.mp4/25.jpg
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# [([], 25)]
# Frames in each video which are not detected : [[([], 25)]]
# content/drive/MyDrive/person-modeltest/person-identify/output/ ['content/drive/MyDrive/tmp/cctvbh90piyo.zip/av-roundabout_pz3dg56a.mp4']
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2592x1520 at 0x7F05B6AE7B50>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6AE7AC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6AE6020>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B07850>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B078B0>]
# (func1 pid=52617) Person of Interest detected in Frame No. 25
# /tmp/cctv7ydkp1ne.zip
# /tmp/cctv7ydkp1ne.zip /tmp/Query_Imageuv8sz1es.PNG
# /tmp/cctv7ydkp1ne.zip/av-roundabout_pz3dg56a.mp4
# ['content/drive/MyDrive/tmp/cctv7ydkp1ne.zip/av-roundabout_pz3dg56a.mp4']
# /tmp/Query_Imageuv8sz1es.PNG is the query image uploaded
# ['content/drive/MyDrive/tmp/cctv7ydkp1ne.zip/av-roundabout_pz3dg56a.mp4']
# Directory already exists
# Directory already exists
# Output Directory already exists
# Face Recognition Directory already exists
# Person Identification Directory already exists
# Analyzing video  av-roundabout_pz3dg56a.mp4
# fps 25
# (func1 pid=52617) content/drive/MyDrive/tmp/cctv7ydkp1ne.zip/av-roundabout_pz3dg56a.mp4 FILENAME
# (func1 pid=52617) < cv2.VideoCapture 0x7f372c101fd0>
# (func1 pid=52617) content/drive/MyDrive/person-modeltest/person-identify/output/av-roundabout_pz3dg56a.mp4/0.jpg
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 59ms/step
# (func1 pid=52617) Person of Interest detected in Frame No. 0
# (func1 pid=52617) content/drive/MyDrive/person-modeltest/person-identify/output/av-roundabout_pz3dg56a.mp4/25.jpg
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# [([], 25)]
# Frames in each video which are not detected : [[([], 25)]]
# content/drive/MyDrive/person-modeltest/person-identify/output/ ['content/drive/MyDrive/tmp/cctv7ydkp1ne.zip/av-roundabout_pz3dg56a.mp4']
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2592x1520 at 0x7F05B6B35870>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B35840>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B358A0>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B35930>, <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x138 at 0x7F05B6B359C0>]
# (func1 pid=52617) Person of Interest detected in Frame No. 25

# %%
demo.close()
# Out:
# Closing server running on port: 7860
